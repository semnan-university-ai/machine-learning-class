# %%
def nott(A):
  if A == False:
      return True
  elif A == True: 
      return False
print("A", "NOT")
print("1", nott(1))
print("0", nott(0))
# Out:
# A NOT
# 1 False
# 0 True

# %%
import pandas
from sklearn import tree
import pydotplus
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import matplotlib.image as pltimg
df = pandas.read_csv("/content/NOT")
print(df)
features = ['A']
X = df[features]
y = df['NOT']
print(df)
dtree = DecisionTreeClassifier()
dtree = dtree.fit(X, y)
data = tree.export_graphviz(dtree, out_file=None, feature_names=features)
graph = pydotplus.graph_from_dot_data(data)
graph.write_png('NOT.png')

img=pltimg.imread('NOT.png')
imgplot = plt.imshow(img)
plt.show()
# Out:
#    A  NOT
# 0  0    1
# 1  1    0
#    A  NOT
# 0  0    1
# 1  1    0
