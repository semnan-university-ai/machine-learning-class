# %%
from wordcloud_fa import WordCloudFa
import numpy as np
import pandas as pd
from PIL import Image
from matplotlib.image import imread
import re
import matplotlib.pyplot as plt



with open('news_data.txt', 'r' , encoding='utf-16') as file:
    text = file.read()
mask_image = np.array(Image.open("mask.png"))
Word_cloud = WordCloudFa(mask=mask_image, 
                       background_color="#f2f2f2",
                        max_font_size=40,
                        min_font_size=15,  
                        scale=1,
                        collocations=False,
                        no_reshape=False, 
                        remove_unhandled_utf_characters=True,  
                        persian_normalize=False, 
                        include_numbers=False )
Word_cloud.add_stop_words_from_file("stop-words.txt"),
frequencies = Word_cloud.process_text(text)
cloud = Word_cloud.generate_from_frequencies(frequencies)
print("کل اخبار")
plt.imshow(cloud)
plt.show()
# Out:
# کل اخبار

# %%
from wordcloud_fa import WordCloudFa
import numpy as np
import pandas as pd
from PIL import Image
from matplotlib.image import imread
import re
import matplotlib.pyplot as plt



with open('news_mahmoudi(1).txt', 'r' , encoding='utf-8') as file:
    text = file.read()
mask_image = np.array(Image.open("mask.png"))
Word_cloud = WordCloudFa(mask=mask_image, 
                       background_color="#f2f2f2",
                        max_font_size=40,
                        min_font_size=15,  
                        scale=11,
                        collocations=False,
                        no_reshape=False, 
                        remove_unhandled_utf_characters=True,  
                        persian_normalize=False, 
                        include_numbers=False )
Word_cloud.add_stop_words_from_file("stop-words.txt"),
frequencies = Word_cloud.process_text(text)
cloud = Word_cloud.generate_from_frequencies(frequencies)
print("اقتصادی")
plt.imshow(cloud)
plt.show()
# Out:
# اقتصادی

# %%
from wordcloud_fa import WordCloudFa
import numpy as np
import pandas as pd
from PIL import Image
from matplotlib.image import imread
import re
import matplotlib.pyplot as plt



with open('news_mahmoudi(20).txt', 'r' , encoding='utf-8') as file:
    text = file.read()
mask_image = np.array(Image.open("mask.png"))
Word_cloud = WordCloudFa(mask=mask_image, 
                       background_color="#f2f2f2",
                        max_font_size=40,
                        min_font_size=15,  
                        scale=11,
                        collocations=False,
                        no_reshape=False, 
                        remove_unhandled_utf_characters=True,  
                        persian_normalize=False, 
                        include_numbers=False )
Word_cloud.add_stop_words_from_file("stop-words.txt"),
frequencies = Word_cloud.process_text(text)
cloud = Word_cloud.generate_from_frequencies(frequencies)
print("سیاسی")
plt.imshow(cloud)
plt.show()
# Out:
# سیاسی

# %%
from wordcloud_fa import WordCloudFa
import numpy as np
import pandas as pd
from PIL import Image
from matplotlib.image import imread
import re
import matplotlib.pyplot as plt



with open('news_mahmoudi(10).txt', 'r' , encoding='utf-8') as file:
    text = file.read()
mask_image = np.array(Image.open("mask.png"))
Word_cloud = WordCloudFa(mask=mask_image, 
                       background_color="#f2f2f2",
                        max_font_size=40,
                        min_font_size=15,  
                        scale=11,
                        collocations=False,
                        no_reshape=False, 
                        remove_unhandled_utf_characters=True,  
                        persian_normalize=False, 
                        include_numbers=False )
Word_cloud.add_stop_words_from_file("stop-words.txt"),
frequencies = Word_cloud.process_text(text)
cloud = Word_cloud.generate_from_frequencies(frequencies)
print("ورزشی")
plt.imshow(cloud)
plt.show()
# Out:
# ورزشی

# %%
from wordcloud_fa import WordCloudFa
import numpy as np
import pandas as pd
from PIL import Image
from matplotlib.image import imread
import re
import matplotlib.pyplot as plt



with open('news_mahmoudi(9).txt', 'r' , encoding='utf-8') as file:
    text = file.read()
mask_image = np.array(Image.open("mask.png"))
Word_cloud = WordCloudFa(mask=mask_image, 
                       background_color="#f2f2f2",
                        max_font_size=40,
                        min_font_size=15,  
                        scale=11,
                        collocations=False,
                        no_reshape=False, 
                        remove_unhandled_utf_characters=True,  
                        persian_normalize=False, 
                        include_numbers=False )
Word_cloud.add_stop_words_from_file("stop-words.txt"),
frequencies = Word_cloud.process_text(text)
cloud = Word_cloud.generate_from_frequencies(frequencies)
print("پزشکی")
plt.imshow(cloud)
plt.show()
# Out:
# پزشکی
