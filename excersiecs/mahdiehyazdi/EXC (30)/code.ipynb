# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %%
news = pd.read_csv('./gdrive/MyDrive/news_data.txt', encoding='utf-8')
news.head()
# Out:
#                                                 news
# 0  ﻿"برگزاری جلسه هیئت دولت به ریاست مخبر/ آغاز ب...
# 1  رئیس‌جمهور ازبکستان در دیدار با رئیسی: از هر ن...
# 2  لیست بازیکنان استقلال برای بازی با صنعت نفت اع...
# 3   مجلس به دنبال بستنِ راهِ «تنفسِ» جنگل‌های شما...
# 4  آخرین آمار کرونا در ایران، ۱۳ آذر ۱۴۰۰: فوت ۵۸...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

document = news['news'].values.astype("U")

# %%
vector = TfidfVectorizer(stop_words='english')
features = vector.fit_transform(doc)

k = 5
model = KMeans(n_clusters=k, init='k-means++', max_iter=100, n_init=1)
model.fit(features)

news['type'] = model.labels_
news.head()
# Out:
#                                                 news  type
# 0  ﻿"برگزاری جلسه هیئت دولت به ریاست مخبر/ آغاز ب...     2
# 1  رئیس‌جمهور ازبکستان در دیدار با رئیسی: از هر ن...     3
# 2  لیست بازیکنان استقلال برای بازی با صنعت نفت اع...     3
# 3   مجلس به دنبال بستنِ راهِ «تنفسِ» جنگل‌های شما...     2
# 4  آخرین آمار کرونا در ایران، ۱۳ آذر ۱۴۰۰: فوت ۵۸...     1

# %%
clusters = news.groupby('type')
for cluster in clusters.groups:
  my = open('type'+ str(cluster) + '.txt', 'w')
  data = clusters.get_group(cluster)[['news']]
  my.write(data.to_csv(index_label='id'))
  my.close()

# %%
print("cluster :\n")

order_centeroids = model.cluster_centers_.argsort()[:,::-1]
terms = vector.get_feature_names()
for i in range(k):
  print("cluster %d:" %i)
  for j in order_centeroids[i, :10]:
    print('%s' %terms[j])
  print('-----------------')
# Out:
# cluster centroids:
#
# cluster 0:
# مسکن
# تمدید
# نهضت
# نام
# ثبت
# عراق
# از
# آمریکا
# خارجه
# معافیت
# -----------------
# cluster 1:
# حادثه
# سمنان
# ۵۸
# نفر
# در
# احمر
# هلال
# ۱۳
# محور
# کیلومتر
# -----------------
# cluster 2:
# در
# به
# از
# این
# که
# با
# های
# می
# است
# را
# -----------------
# cluster 3:
# در
# به
# کرونا
# از
# واکسن
# دانشجویان
# با
# که
# مسکن
# این
# -----------------
# cluster 4:
# لیگ
# تیم
# ورزشگاه
# مس
# دربی
# جدول
# برتر
# تساوی
# در
# فوتبال
# -----------------
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
